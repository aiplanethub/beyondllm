# %%
# !pip install beyondllm

# %%
from beyondllm import source,retrieve,embeddings,llms,generator
import os
from getpass import getpass
os.environ['OPENAI_API_KEY'] = getpass("Your OPENAI_API_KEY:")

data = source.fit("/content/build-career-in-ai.pdf",dtype="pdf",chunk_size=1024,chunk_overlap=0)
embed_model = embeddings.OpenAIEmbeddings()

# %%
from beyondllm.retrieve import auto_retriever

retriever = auto_retriever(
    data=data,
    embed_model=embed_model,
    type="cross-rerank",
    top_k=5,
    reranker="cross-encoder/ms-marco-MiniLM-L-2-v2",
)
# Out:
# The feature you're trying to use requires a additional libraries:sentence-transformers, torch. Would you like to install it now? [y/N]: y

# %%
llm = llms.ChatOpenAIModel()
pipeline = generator.Generate(question="How to get into AI?",retriever=retriever,llm=llm)

print(pipeline.call()) #AI response
# Out:
# LLM is explicitly disabled. Using MockLLM.
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/62.5M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# To get into AI, you can follow these steps:
#
# 1. Learn foundational technical skills: It's important to understand machine learning models like linear regression, neural networks, decision trees, etc. Deep learning is also essential. Additionally, having software development skills and knowledge of relevant math concepts like linear algebra and probability is beneficial.
#
# 2. Work on projects: Gain practical experience by working on AI projects. Collaborating with stakeholders and building a portfolio of projects can help demonstrate your skills to potential employers.
#
# 3. Find the right job: Use informational interviews to learn more about different AI roles and companies. Networking with industry professionals and seeking guidance from experienced professionals can help you find the right job within the AI field.
#
# By following these steps, you can start your journey into the field of AI and work towards building a successful career in this growing industry.
